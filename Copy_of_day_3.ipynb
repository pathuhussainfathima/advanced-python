# %% [markdown]
# <a href="https://colab.research.google.com/github/pathuhussainfathima/advanced-python/blob/main/Copy_of_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
square=lambda x:x*x
square(5)
# Out:
# 25

# %%
addition=lambda x,y:x+y
addition(10,20)
# Out:
# 30

# %%
is_pass=lambda marks:"pass" if marks>40 else "fail"
is_pass(55)
# Out:
# 'pass'

# %%
def square(x):
  sq=x*x
  return sq

numbers=[1,2,3,4,5]
squares=map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
sq=lambda x:x*x
numbers=[1,2,3,4,5]
squares=map(sq,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
squares=list(map(lambda x:x*x,numbers))
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a=[1,2,3]
list_b=[4,5,6]
sum_lists=list(map(lambda x,y:x+y,list_a,list_b))
sum_lists
# Out:
# [5, 7, 9]

# %% [markdown]
# filter out negative values by using lambda

# %%
numbers=[-3,-2,-7,9,4,8,1,-5,6,-3]
positive_numbers=list(filter(lambda x:x>0,numbers))
positive_numbers
# Out:
# [9, 4, 8, 1, 6]
